# %%
import pandas as pd
import random

# %%
# bureau= pd.read_csv('https://downloaddataaia.blob.core.windows.net/aiadata/bureau.csv',nrows=80000)
# bureau.head()
p = 0.01
bureau = pd.read_csv('https://downloaddataaia.blob.core.windows.net/aiadata/bureau.csv',header=0, skiprows=lambda i: i>0 and random.random() > p)

# %%
Column_desc = pd.read_csv('https://downloaddataaia.blob.core.windows.net/aiadata/HomeCredit_columns_description.csv',encoding = "ISO-8859-1")
pd.set_option('display.max_colwidth', -1)
Column_desc.loc[Column_desc['Table'] == 'bureau.csv']
# Out:
#      Unnamed: 0       Table                     Row  \
# 122  125         bureau.csv  SK_ID_CURR
# 123  126         bureau.csv  SK_BUREAU_ID
# 124  127         bureau.csv  CREDIT_ACTIVE
# 125  128         bureau.csv  CREDIT_CURRENCY
# 126  129         bureau.csv  DAYS_CREDIT
# 127  130         bureau.csv  CREDIT_DAY_OVERDUE
# 128  131         bureau.csv  DAYS_CREDIT_ENDDATE
# 129  132         bureau.csv  DAYS_ENDDATE_FACT
# 130  133         bureau.csv  AMT_CREDIT_MAX_OVERDUE
# 131  134         bureau.csv  CNT_CREDIT_PROLONG
# 132  135         bureau.csv  AMT_CREDIT_SUM
# 133  136         bureau.csv  AMT_CREDIT_SUM_DEBT
# 134  137         bureau.csv  AMT_CREDIT_SUM_LIMIT
# 135  138         bureau.csv  AMT_CREDIT_SUM_OVERDUE
# 136  139         bureau.csv  CREDIT_TYPE
# 137  140         bureau.csv  DAYS_CREDIT_UPDATE
# 138  141         bureau.csv  AMT_ANNUITY
#
#                                                                                                              Description  \
# ...

# %%
bureau.shape
# Out:
# (17127, 17)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid",font_scale=0.9)
plot = sns.barplot(x="CREDIT_ACTIVE",y="DAYS_CREDIT_ENDDATE",data=bureau)
plot.set(xlabel = 'CREDIT_ACTIVE',ylabel = 'AMT',title ='CREDIT_TYPE VS AMT OVERDUE')
# Out:
# [Text(0,0.5,'AMT'),
#  Text(0.5,0,'CREDIT_ACTIVE'),
#  Text(0.5,1,'CREDIT_TYPE VS AMT OVERDUE')]

# %%
bureau.describe()
# Out:
#           SK_ID_CURR  SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# count  17127.000000   1.712700e+04  17127.000000  17127.000000
# mean   278170.438956  5.920588e+06 -1141.222164   0.697554
# std    102946.532105  5.310406e+05  794.294062    33.406638
# min    100001.000000  5.000018e+06 -2922.000000   0.000000
# 25%    188479.000000  5.460339e+06 -1663.500000   0.000000
# 50%    278754.000000  5.924448e+06 -991.000000    0.000000
# 75%    366582.000000  6.377852e+06 -470.000000    0.000000
# max    456250.000000  6.843411e+06  0.000000      2456.000000
#
#        DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# count  16079.000000         10844.000000       5.833000e+03
# mean   593.781952          -1019.210347        3.198482e+03
# std    5199.418907          711.665152         3.703312e+04
# min   -2806.000000         -3042.000000        0.000000e+00
# 25%   -1125.500000         -1492.250000        0.000000e+00
# ...

# %%
bureau.isnull().sum()
# Out:
# SK_ID_CURR                0
# SK_ID_BUREAU              0
# CREDIT_ACTIVE             0
# CREDIT_CURRENCY           0
# DAYS_CREDIT               0
# CREDIT_DAY_OVERDUE        0
# DAYS_CREDIT_ENDDATE       1048
# DAYS_ENDDATE_FACT         6283
# AMT_CREDIT_MAX_OVERDUE    11294
# CNT_CREDIT_PROLONG        0
# AMT_CREDIT_SUM            0
# AMT_CREDIT_SUM_DEBT       2612
# AMT_CREDIT_SUM_LIMIT      6063
# AMT_CREDIT_SUM_OVERDUE    0
# CREDIT_TYPE               0
# DAYS_CREDIT_UPDATE        0
# AMT_ANNUITY               12291
# dtype: int64

# %%
bureau['CREDIT_ACTIVE'].value_counts()
# Out:
# Closed    10805
# Active    6261
# Sold      61
# Name: CREDIT_ACTIVE, dtype: int64

# %%
bureau['CREDIT_CURRENCY'].value_counts()
# Out:
# currency 1    17109
# currency 2    15
# currency 3    2
# currency 4    1
# Name: CREDIT_CURRENCY, dtype: int64

# %%
bureau['CREDIT_TYPE'].value_counts()
# Out:
# Consumer credit                                 12523
# Credit card                                     3995
# Car loan                                        272
# Mortgage                                        171
# Microloan                                       123
# Loan for business development                   23
# Another type of loan                            12
# Unknown type of loan                            4
# Cash loan (non-earmarked)                       2
# Loan for the purchase of equipment              1
# Loan for purchase of shares (margin lending)    1
# Name: CREDIT_TYPE, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def barplot(col):
          
    plt.figure(figsize=(15,5))
    sns.set(style="darkgrid")
    sns.countplot(bureau[col]).set_title("%s Frequency" %col)

# %%
barplot('CREDIT_ACTIVE')

# %%
barplot('CREDIT_TYPE')

# %%
# for column,dtype in zip(bureau.columns,bureau.dtypes):
#     cat_list = []
#     if dtype =='object':
#         cat_list.append(column)

# %%
def displotgen(col):
    
    plt.figure(figsize=(15,5))
    plt.title('Distribution of %s' % col)
    sns.distplot(bureau[col].dropna(), bins=100)

# %%
displotgen('DAYS_CREDIT')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('CREDIT_DAY_OVERDUE')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('DAYS_CREDIT_ENDDATE')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('DAYS_ENDDATE_FACT')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_CREDIT_MAX_OVERDUE')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('CNT_CREDIT_PROLONG')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_CREDIT_SUM')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_CREDIT_SUM_DEBT')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_CREDIT_SUM_LIMIT')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_CREDIT_SUM_OVERDUE')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('DAYS_CREDIT_UPDATE')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
displotgen('AMT_ANNUITY')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
 def check_duplicates():

     col_list = []

     for column in bureau.columns:
         
         col_list.append(column)
         print(column,':',bureau.duplicated(subset=column).any())

# %%
check_duplicates()
# Out:
# SK_ID_CURR : True
# SK_ID_BUREAU : False
# CREDIT_ACTIVE : True
# CREDIT_CURRENCY : True
# DAYS_CREDIT : True
# CREDIT_DAY_OVERDUE : True
# DAYS_CREDIT_ENDDATE : True
# DAYS_ENDDATE_FACT : True
# AMT_CREDIT_MAX_OVERDUE : True
# CNT_CREDIT_PROLONG : True
# AMT_CREDIT_SUM : True
# AMT_CREDIT_SUM_DEBT : True
# AMT_CREDIT_SUM_LIMIT : True
# AMT_CREDIT_SUM_OVERDUE : True
# CREDIT_TYPE : True
# DAYS_CREDIT_UPDATE : True
# AMT_ANNUITY : True

# %%
credit_type_list = pd.Categorical(bureau['CREDIT_TYPE']).unique()

# %%
bureau = bureau.drop(columns=['DAYS_ENDDATE_FACT','AMT_CREDIT_MAX_OVERDUE'])

# %%
#bureau['AMT_ANNUITY','AMT_CREDIT_SUM_LIMIT'] = bureau['AMT_ANNUITY','AMT_CREDIT_SUM_LIMIT'].fillna(0)
bureau.update(bureau[['AMT_ANNUITY','AMT_CREDIT_SUM_LIMIT']].fillna(0))

# %%
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0  312983      5714725       Closed        currency 1     -1278
# 1  227903      5714765       Closed        currency 1     -1930
# 2  262765      5714917       Closed        currency 1     -2395
# 3  273814      5714965       Closed        currency 1     -751
# 4  233056      5715042       Closed        currency 1     -1381
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  CNT_CREDIT_PROLONG  \
# 0  0                  NaN                   0
# 1  0                  -1838.0               0
# 2  0                  -2181.0               0
# 3  0                  -567.0                0
# 4  0                  -1200.0               0
#
#    AMT_CREDIT_SUM  AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  \
# 0  66780.00        0.0                  0.0
# 1  109138.50      NaN                   0.0
# 2  17361.99        0.0                  0.0
# 3  44950.50        0.0                  0.0
# ...

# %%
status = pd.Categorical(bureau['CREDIT_ACTIVE']).unique()

# %%
#https://stackoverflow.com/questions/43222878/iterate-over-pandas-dataframe-and-update-the-value-attributeerror-cant-set-a
for row in bureau.itertuples(index=True, name='Pandas'):
    
    if (pd.isnull(row[10])):
       if row[3]=='Closed':
          bureau.set_value(row.Index, 'AMT_CREDIT_SUM_DEBT', 0.0)
       else:
          val = row[9]
          bureau.set_value(row.Index, 'AMT_CREDIT_SUM_DEBT', val)

# %%
means_CA = bureau.groupby('CREDIT_ACTIVE')['DAYS_CREDIT_ENDDATE'].mean()
active_mean = means_CA[0].round()
active_mean
# Out:
# 2660.0

# %%
for row in bureau.itertuples(index=True,name='Pandas'):
    
    if (pd.isnull(row[7])):
       if row[3]=='Active':
          bureau.set_value(row.Index,'DAYS_CREDIT_ENDDATE',active_mean)
       else:
          bureau.set_value(row.Index,'DAYS_CREDIT_ENDDATE', 0)

# %%
bureau.head(1000)
# Out:
#      SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0    312983      5714725       Closed        currency 1     -1278
# 1    227903      5714765       Closed        currency 1     -1930
# 2    262765      5714917       Closed        currency 1     -2395
# 3    273814      5714965       Closed        currency 1     -751
# 4    233056      5715042       Closed        currency 1     -1381
# 5    157200      5715109       Active        currency 1     -601
# 6    431472      5715390       Closed        currency 1     -1766
# 7    381062      5715413       Closed        currency 1     -1319
# 8    342165      5715426       Active        currency 1     -190
# 9    101060      5715560       Active        currency 1     -709
# 10   298496      5715591       Closed        currency 1     -1039
# 11   298496      5715592       Active        currency 1     -1038
# 12   250967      5715625       Closed        currency 1     -658
# ...
